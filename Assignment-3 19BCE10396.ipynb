# %% [markdown]
# ## Assignment-3

# %% [markdown]
# ## 1.Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Load the dataset

# %%
headers = ["Id","Open Date","City","City Group","Type","P1","P2","P3","P4","P5","P6","P7","P8","P9","P10","P11","P12","P13","P14","P15","P16","P17","P18","P19","P20","P21","P22","P23","P24","P25","P26","P27","P28","P29","P30","P31","P32","P33","P34","P35","P36","P37","revenue"]

# %%
df = pd.read_csv("C:/Users/Sakshi/Desktop/restaurant_revenue.csv",names = headers)

# %%
df.head()
# Out:
#    Id   Open Date        City  City Group  Type  P1   P2   P3   P4  P5  ...  \
# 0  Id   Open Date        City  City Group  Type  P1   P2   P3   P4  P5  ...
# 1   0  07/17/1999    İstanbul  Big Cities    IL   4  5.0  4.0  4.0   2  ...
# 2   1  02/14/2008      Ankara  Big Cities    FC   4  5.0  4.0  4.0   1  ...
# 3   2  03/09/2013  Diyarbakır       Other    IL   2  4.0  2.0  5.0   2  ...
# 4   3  02/02/2012       Tokat       Other    IL   6  4.5  6.0  6.0   4  ...
#
#    P29  P30  P31  P32  P33  P34  P35  P36  P37    revenue
# 0  P29  P30  P31  P32  P33  P34  P35  P36  P37    revenue
# 1  3.0    5    3    4    5    5    4    3    4  5653753.0
# 2  3.0    0    0    0    0    0    0    0    0  6923131.0
# 3  3.0    0    0    0    0    0    0    0    0  2055379.0
# 4  7.5   25   12   10    6   18   12   12    6  2675511.0
#
# [5 rows x 43 columns]

# %% [markdown]
# ## 3.Data Preprocessing

# %%
df.replace("?",np.nan,inplace=True)
df.head()
# Out:
#    Id   Open Date        City  City Group  Type  P1   P2   P3   P4  P5  ...  \
# 0  Id   Open Date        City  City Group  Type  P1   P2   P3   P4  P5  ...
# 1   0  07/17/1999    İstanbul  Big Cities    IL   4  5.0  4.0  4.0   2  ...
# 2   1  02/14/2008      Ankara  Big Cities    FC   4  5.0  4.0  4.0   1  ...
# 3   2  03/09/2013  Diyarbakır       Other    IL   2  4.0  2.0  5.0   2  ...
# 4   3  02/02/2012       Tokat       Other    IL   6  4.5  6.0  6.0   4  ...
#
#    P29  P30  P31  P32  P33  P34  P35  P36  P37    revenue
# 0  P29  P30  P31  P32  P33  P34  P35  P36  P37    revenue
# 1  3.0    5    3    4    5    5    4    3    4  5653753.0
# 2  3.0    0    0    0    0    0    0    0    0  6923131.0
# 3  3.0    0    0    0    0    0    0    0    0  2055379.0
# 4  7.5   25   12   10    6   18   12   12    6  2675511.0
#
# [5 rows x 43 columns]

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#       Id  Open Date   City  City Group   Type     P1     P2     P3     P4  \
# 0  False      False  False       False  False  False  False  False  False
# 1  False      False  False       False  False  False  False  False  False
# 2  False      False  False       False  False  False  False  False  False
# 3  False      False  False       False  False  False  False  False  False
# 4  False      False  False       False  False  False  False  False  False
#
#       P5  ...    P29    P30    P31    P32    P33    P34    P35    P36    P37  \
# 0  False  ...  False  False  False  False  False  False  False  False  False
# 1  False  ...  False  False  False  False  False  False  False  False  False
# 2  False  ...  False  False  False  False  False  False  False  False  False
# 3  False  ...  False  False  False  False  False  False  False  False  False
# 4  False  ...  False  False  False  False  False  False  False  False  False
#
#    revenue
# 0    False
# 1    False
# 2    False
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# Id
# False    138
# Name: Id, dtype: int64
#
# Open Date
# False    138
# Name: Open Date, dtype: int64
#
# City
# False    138
# Name: City, dtype: int64
#
# City Group
# False    138
# Name: City Group, dtype: int64
#
# Type
# False    138
# Name: Type, dtype: int64
#
# P1
# False    138
# Name: P1, dtype: int64
#
# P2
# False    138
# Name: P2, dtype: int64
#
# P3
# False    138
# Name: P3, dtype: int64
#
# P4
# False    138
# Name: P4, dtype: int64
#
# P5
# False    138
# Name: P5, dtype: int64
#
# P6
# False    138
# Name: P6, dtype: int64
#
# P7
# False    138
# Name: P7, dtype: int64
#
# P8
# False    138
# Name: P8, dtype: int64
#
# P9
# False    138
# Name: P9, dtype: int64
#
# P10
# False    138
# Name: P10, dtype: int64
#
# P11
# False    138
# Name: P11, dtype: int64
#
# P12
# False    138
# Name: P12, dtype: int64
#
# P13
# False    138
# Name: P13, dtype: int64
#
# P14
# False    138
# Name: P14, dtype: int64
#
# P15
# False    138
# Name: P15, dtype: int64
#
# P16
# ...

# %%
df['P1'] = pd.to_numeric(df['P1'],errors='coerce')

# %%
avg_P1 = df["P1"].astype("float").mean(axis=0)
print("Average of P1:", avg_P1)
# Out:
# Average of P1: 4.014598540145985

# %%
df["P1"].replace(np.nan, avg_P1, inplace=True)

# %%
df['P2'] = pd.to_numeric(df['P2'],errors='coerce')

# %%
avg_P2 = df["P2"].astype("float").mean(axis=0)
print("Average of P2", avg_P2)
# Out:
# Average of P2 4.408759124087592

# %%
df["P2"].replace(np.nan, avg_P2, inplace=True)

# %%
df['P3'] = pd.to_numeric(df['P3'],errors='coerce')

# %%
avg_P3 = df["P3"].astype("float").mean(axis=0)
print("Average of P3", avg_P3)
# Out:
# Average of P3 4.317518248175182

# %%
df["P3"].replace(np.nan, avg_P3, inplace=True)

# %%
df['P4'] = pd.to_numeric(df['P4'],errors='coerce')

# %%
avg_P4 = df["P4"].astype("float").mean(axis=0)
print("Average of P4", avg_P4)
# Out:
# Average of P4 4.372262773722627

# %%
df["P4"].replace(np.nan, avg_P4, inplace=True)

# %%
df['P5'] = pd.to_numeric(df['P5'],errors='coerce')

# %%
avg_P5 = df["P5"].astype("float").mean(axis=0)
print("Average of P5", avg_P5)
# Out:
# Average of P5 2.0072992700729926

# %%
df["P5"].replace(np.nan, avg_P5, inplace=True)

# %%
df['P6'] = pd.to_numeric(df['P6'],errors='coerce')

# %%
avg_P6 = df["P6"].astype("float").mean(axis=0)
print("Average of P6", avg_P6)
# Out:
# Average of P6 3.3576642335766422

# %%
df["P6"].replace(np.nan, avg_P6, inplace=True)

# %%
df['P7'] = pd.to_numeric(df['P7'],errors='coerce')

# %%
avg_P7 = df["P7"].astype("float").mean(axis=0)
print("Average of P7", avg_P7)
# Out:
# Average of P7 5.423357664233577

# %%
df["P7"].replace(np.nan, avg_P7, inplace=True)

# %%
df['P8'] = pd.to_numeric(df['P8'],errors='coerce')

# %%
avg_P8 = df["P8"].astype("float").mean(axis=0)
print("Average of P8", avg_P8)
# Out:
# Average of P8 5.153284671532846

# %%
df["P8"].replace(np.nan, avg_P8, inplace=True)

# %%
df['P9'] = pd.to_numeric(df['P9'],errors='coerce')

# %%
avg_P9 = df["P9"].astype("float").mean(axis=0)
print("Average of P9", avg_P9)
# Out:
# Average of P9 5.445255474452555

# %%
df["P9"].replace(np.nan, avg_P9, inplace=True)

# %%
df['P10'] = pd.to_numeric(df['P10'],errors='coerce')

# %%
avg_P10 = df["P10"].astype("float").mean(axis=0)
print("Average of P10", avg_P10)
# Out:
# Average of P10 5.489051094890511

# %%
df["P10"].replace(np.nan, avg_P10, inplace=True)

# %%
df['P1'].value_counts().idxmax()
# Out:
# 2.0

# %%
df['P2'].value_counts().idxmax()
# Out:
# 5.0

# %%
df['P3'].value_counts().idxmax()
# Out:
# 4.0

# %%
df['P4'].value_counts().idxmax()
# Out:
# 4.0

# %%
df['P5'].value_counts().idxmax()
# Out:
# 2.0

# %%
df["P1"].replace(np.nan, 'two', inplace=True)

# %%
df.dropna(subset=['P2'], axis=0, inplace=True)

df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    Id   Open Date        City  City Group  Type        P1        P2        P3  \
# 0  Id   Open Date        City  City Group  Type  4.014599  4.408759  4.317518
# 1   0  07/17/1999    İstanbul  Big Cities    IL  4.000000  5.000000  4.000000
# 2   1  02/14/2008      Ankara  Big Cities    FC  4.000000  5.000000  4.000000
# 3   2  03/09/2013  Diyarbakır       Other    IL  2.000000  4.000000  2.000000
# 4   3  02/02/2012       Tokat       Other    IL  6.000000  4.500000  6.000000
#
#          P4        P5  ...  P29  P30  P31  P32  P33  P34  P35  P36  P37  \
# 0  4.372263  2.007299  ...  P29  P30  P31  P32  P33  P34  P35  P36  P37
# 1  4.000000  2.000000  ...  3.0    5    3    4    5    5    4    3    4
# 2  4.000000  1.000000  ...  3.0    0    0    0    0    0    0    0    0
# 3  5.000000  2.000000  ...  3.0    0    0    0    0    0    0    0    0
# 4  6.000000  4.000000  ...  7.5   25   12   10    6   18   12   12    6
#
#      revenue
# 0    revenue
# 1  5653753.0
# 2  6923131.0
# ...

# %%
df.dtypes
# Out:
# Id             object
# Open Date      object
# City           object
# City Group     object
# Type           object
# P1            float64
# P2            float64
# P3            float64
# P4            float64
# P5            float64
# P6            float64
# P7            float64
# P8            float64
# P9            float64
# P10           float64
# P11            object
# P12            object
# P13            object
# P14            object
# P15            object
# P16            object
# P17            object
# P18            object
# P19            object
# P20            object
# P21            object
# P22            object
# P23            object
# P24            object
# P25            object
# P26            object
# P27            object
# P28            object
# P29            object
# P30            object
# P31            object
# P32            object
# P33            object
# P34            object
# P35            object
# P36            object
# ...

# %%
# Data Standardization
df['P1'] = 235/df['P1']
df.rename(columns={'P1':'P-1'}, inplace=True)
df['P2'] = 235/df['P2']
df.rename(columns={'P2':'P-2'}, inplace=True)
df.head()
# Out:
#    Id   Open Date        City  City Group  Type         P-1        P-2  \
# 0  Id   Open Date        City  City Group  Type   58.536364  53.302980
# 1   0  07/17/1999    İstanbul  Big Cities    IL   58.750000  47.000000
# 2   1  02/14/2008      Ankara  Big Cities    FC   58.750000  47.000000
# 3   2  03/09/2013  Diyarbakır       Other    IL  117.500000  58.750000
# 4   3  02/02/2012       Tokat       Other    IL   39.166667  52.222222
#
#          P3        P4        P5  ...  P29  P30  P31  P32  P33  P34  P35  P36  \
# 0  4.317518  4.372263  2.007299  ...  P29  P30  P31  P32  P33  P34  P35  P36
# 1  4.000000  4.000000  2.000000  ...  3.0    5    3    4    5    5    4    3
# 2  4.000000  4.000000  1.000000  ...  3.0    0    0    0    0    0    0    0
# 3  2.000000  5.000000  2.000000  ...  3.0    0    0    0    0    0    0    0
# 4  6.000000  6.000000  4.000000  ...  7.5   25   12   10    6   18   12   12
#
#    P37    revenue
# 0  P37    revenue
# 1    4  5653753.0
# ...

# %%
# Data Normalization

df['P-1'] = df['P-1']/df['P-1'].max()
df['P-2'] = df['P-2']/df['P-2'].max()
df['P3'] = df['P3']/df['P3'].max()
df[['P-1','P-2','P3']].head()
# Out:
#         P-1       P-2        P3
# 0  0.249091  0.226821  0.575669
# 1  0.250000  0.200000  0.533333
# 2  0.250000  0.200000  0.533333
# 3  0.500000  0.250000  0.266667
# 4  0.166667  0.222222  0.800000

# %%
# Binning-1
df['P-1'] = df['P-1'].astype("float", copy=True)
plt.hist(df['P-1'])

# Set x&y-labels and plot title
plt.xlabel('P-1')
plt.ylabel('count')
plt.title('Revenue of 1')
# Out:
# Text(0.5, 1.0, 'Revenue of 1')

# %%
# Binning-2
bins = np.linspace(min(df['P-1']),max(df['P-1']),4)
bins
# Out:
# array([0.08333333, 0.38888889, 0.69444444, 1.        ])

# %%
group_names = ['Low','Medium','High']
df['P1-binned'] = pd.cut(df['P-1'], bins, labels=group_names, include_lowest=True)
df[['P-1','P1-binned']].head(20)
# Out:
#          P-1 P1-binned
# 0   0.249091       Low
# 1   0.250000       Low
# 2   0.250000       Low
# 3   0.500000    Medium
# 4   0.166667       Low
# 5   0.333333       Low
# 6   0.166667       Low
# 7   0.500000    Medium
# 8   0.250000       Low
# 9   1.000000      High
# 10  0.166667       Low
# 11  0.111111       Low
# 12  0.500000    Medium
# 13  0.500000    Medium
# 14  0.250000       Low
# 15  0.500000    Medium
# 16  0.083333       Low
# 17  0.333333       Low
# 18  0.500000    Medium
# 19  0.250000       Low

# %%
df['P1-binned'].value_counts()
# Out:
# Low       93
# Medium    36
# High       9
# Name: P1-binned, dtype: int64

# %%
plt.bar(group_names, df['P1-binned'].value_counts())
plt.xlabel('P-1')
plt.ylabel('count')
plt.title('Revenue of 1')
# Out:
# Text(0.5, 1.0, 'Revenue of 1')

# %%
plt.hist(df['P-1'], bins=3)
plt.xlabel('P-1')
plt.ylabel('count')
plt.title('Revenue of 1')
# Out:
# Text(0.5, 1.0, 'Revenue of 1')

# %%
df.head()
# Out:
#    Id   Open Date        City  City Group  Type       P-1       P-2        P3  \
# 0  Id   Open Date        City  City Group  Type  0.249091  0.226821  0.575669
# 1   0  07/17/1999    İstanbul  Big Cities    IL  0.250000  0.200000  0.533333
# 2   1  02/14/2008      Ankara  Big Cities    FC  0.250000  0.200000  0.533333
# 3   2  03/09/2013  Diyarbakır       Other    IL  0.500000  0.250000  0.266667
# 4   3  02/02/2012       Tokat       Other    IL  0.166667  0.222222  0.800000
#
#          P4        P5  ...  P30  P31  P32  P33  P34  P35  P36  P37    revenue  \
# 0  4.372263  2.007299  ...  P30  P31  P32  P33  P34  P35  P36  P37    revenue
# 1  4.000000  2.000000  ...    5    3    4    5    5    4    3    4  5653753.0
# 2  4.000000  1.000000  ...    0    0    0    0    0    0    0    0  6923131.0
# 3  5.000000  2.000000  ...    0    0    0    0    0    0    0    0  2055379.0
# 4  6.000000  4.000000  ...   25   12   10    6   18   12   12    6  2675511.0
#
#   P1-binned
# 0       Low
# ...

# %%
# Dummy Variables-1
dv1 = pd.get_dummies(df['Type'])
dv1.rename(columns={'IL':'I-L','FC':'F-C','DT':'D-T'}, inplace=True)
dv1.head()
# Out:
#    D-T  F-C  I-L  Type
# 0    0    0    0     1
# 1    0    0    1     0
# 2    0    1    0     0
# 3    0    0    1     0
# 4    0    0    1     0

# %%
# Merging dataframe 'df' and 'dv1'
df = pd.concat([df, dv1], axis=1)

#drop original column "variety" from "df"
df.drop("Type", axis=1, inplace=True)

# %%
df.head()
# Out:
#    Id   Open Date        City  City Group       P-1       P-2        P3  \
# 0  Id   Open Date        City  City Group  0.249091  0.226821  0.575669
# 1   0  07/17/1999    İstanbul  Big Cities  0.250000  0.200000  0.533333
# 2   1  02/14/2008      Ankara  Big Cities  0.250000  0.200000  0.533333
# 3   2  03/09/2013  Diyarbakır       Other  0.500000  0.250000  0.266667
# 4   3  02/02/2012       Tokat       Other  0.166667  0.222222  0.800000
#
#          P4        P5        P6  ...  P33  P34  P35  P36  P37    revenue  \
# 0  4.372263  2.007299  3.357664  ...  P33  P34  P35  P36  P37    revenue
# 1  4.000000  2.000000  2.000000  ...    5    5    4    3    4  5653753.0
# 2  4.000000  1.000000  2.000000  ...    0    0    0    0    0  6923131.0
# 3  5.000000  2.000000  3.000000  ...    0    0    0    0    0  2055379.0
# 4  6.000000  4.000000  4.000000  ...    6   18   12   12    6  2675511.0
#
#   P1-binned D-T F-C I-L
# 0       Low   0   0   0
# 1       Low   0   0   1
# ...

# %%
# Dummy Variables-2
dv2 = pd.get_dummies(df['F-C'])
dv2.rename(columns={'0':'1','1':'0'}, inplace=True)
dv2.head()
# Out:
#    0  1
# 0  1  0
# 1  1  0
# 2  0  1
# 3  1  0
# 4  1  0

# %%
# Merging dataframe 'df' and 'dv2'
df = pd.concat([df, dv2], axis=1)

#drop original column "variety-setosa" from "df"
df.drop("F-C", axis=1, inplace=True)

df.head()
# Out:
#    Id   Open Date        City  City Group       P-1       P-2        P3  \
# 0  Id   Open Date        City  City Group  0.249091  0.226821  0.575669
# 1   0  07/17/1999    İstanbul  Big Cities  0.250000  0.200000  0.533333
# 2   1  02/14/2008      Ankara  Big Cities  0.250000  0.200000  0.533333
# 3   2  03/09/2013  Diyarbakır       Other  0.500000  0.250000  0.266667
# 4   3  02/02/2012       Tokat       Other  0.166667  0.222222  0.800000
#
#          P4        P5        P6  ...  P34  P35  P36  P37    revenue P1-binned  \
# 0  4.372263  2.007299  3.357664  ...  P34  P35  P36  P37    revenue       Low
# 1  4.000000  2.000000  2.000000  ...    5    4    3    4  5653753.0       Low
# 2  4.000000  1.000000  2.000000  ...    0    0    0    0  6923131.0       Low
# 3  5.000000  2.000000  3.000000  ...    0    0    0    0  2055379.0    Medium
# 4  6.000000  4.000000  4.000000  ...   18   12   12    6  2675511.0       Low
#
#   D-T I-L  0  1
# 0   0   0  1  0
# 1   0   1  1  0
# ...

# %%
df.corr()
# Out:
#           P-1       P-2        P3        P4        P5        P6        P7  \
# P-1  1.000000  0.820492 -0.433385 -0.471431 -0.213736 -0.468999 -0.773238
# P-2  0.820492  1.000000 -0.222370 -0.348682 -0.134901 -0.409285 -0.597784
# P3  -0.433385 -0.222370  1.000000  0.443606  0.168891  0.570486  0.651489
# P4  -0.471431 -0.348682  0.443606  1.000000  0.715406  0.595724  0.700482
# P5  -0.213736 -0.134901  0.168891  0.715406  1.000000  0.326524  0.446154
# P6  -0.468999 -0.409285  0.570486  0.595724  0.326524  1.000000  0.738388
# P7  -0.773238 -0.597784  0.651489  0.700482  0.446154  0.738388  1.000000
# P8  -0.401911 -0.214857  0.689173  0.654594  0.447577  0.720144  0.751196
# P9  -0.427470 -0.210161  0.741967  0.675336  0.465662  0.676323  0.775003
# P10 -0.454704 -0.220250  0.764191  0.685416  0.462299  0.654594  0.775642
# D-T  0.255345  0.030817 -0.359934  0.053149  0.212924  0.066226 -0.165744
# I-L -0.156795 -0.032628  0.191828  0.067567  0.043361  0.141713  0.189755
# ...

# %%
sns.regplot(x="P-1", y="P-2", data=df)
plt.ylim(0,)
# Out:
# (0.0, 1.047008045981839)

# %%
df[["P-1","P-2"]].corr()
# Out:
#           P-1       P-2
# P-1  1.000000  0.820492
# P-2  0.820492  1.000000

# %%
sns.regplot(x="P3", y="P4", data=df)
# Out:
# <AxesSubplot:xlabel='P3', ylabel='P4'>

# %%
df[["P3","P4"]].corr()
# Out:
#           P3        P4
# P3  1.000000  0.443606
# P4  0.443606  1.000000

# %%
df['revenue'] = pd.to_numeric(df['revenue'],errors='coerce')

# %%
sns.regplot(x="P6", y="revenue", data=df)
# Out:
# <AxesSubplot:xlabel='P6', ylabel='revenue'>

# %%
df[['P6','revenue']].corr()
# Out:
#                P6   revenue
# P6       1.000000  0.139094
# revenue  0.139094  1.000000

# %% [markdown]
# ## 4. Independent & Dependent

# %%
# dependant variable
y= df['P-1']

# independant variable
x= df.drop('P-1', axis=1)

# %%
x.head()
# Out:
#    Id   Open Date        City  City Group       P-2        P3        P4  \
# 0  Id   Open Date        City  City Group  0.226821  0.575669  4.372263
# 1   0  07/17/1999    İstanbul  Big Cities  0.200000  0.533333  4.000000
# 2   1  02/14/2008      Ankara  Big Cities  0.200000  0.533333  4.000000
# 3   2  03/09/2013  Diyarbakır       Other  0.250000  0.266667  5.000000
# 4   3  02/02/2012       Tokat       Other  0.222222  0.800000  6.000000
#
#          P5        P6         P7  ...  P34  P35  P36  P37    revenue  \
# 0  2.007299  3.357664   5.423358  ...  P34  P35  P36  P37        NaN
# 1  2.000000  2.000000   5.000000  ...    5    4    3    4  5653753.0
# 2  1.000000  2.000000   5.000000  ...    0    0    0    0  6923131.0
# 3  2.000000  3.000000   5.000000  ...    0    0    0    0  2055379.0
# 4  4.000000  4.000000  10.000000  ...   18   12   12    6  2675511.0
#
#   P1-binned D-T I-L  0  1
# 0       Low   0   0  1  0
# 1       Low   0   1  1  0
# 2       Low   0   0  0  1
# ...

# %% [markdown]
# ## 5. Train,Test & Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.10,random_state=1)

# %%
print(x_train.shape) #training input
print(x_test.shape)#testing input
print(y_train.shape) #training output
print(y_test.shape)#testing output
# Out:
# (124, 46)
# (14, 46)
# (124,)
# (14,)

# %% [markdown]
# ## 6. Build ML Algorithms

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train, y_train)

# %%
x_test
# Out:
#       Id   Open Date       City  City Group       P-2        P3   P4   P5  \
# 35    34  03/21/2012   İstanbul  Big Cities  0.200000  0.533333  4.0  1.0
# 33    32  01/17/2009  Şanlıurfa       Other  0.250000  0.400000  4.0  3.0
# 77    76  11/25/2008   İstanbul  Big Cities  0.500000  0.533333  4.0  2.0
# 5      4  05/09/2009  Gaziantep       Other  0.250000  0.400000  4.0  2.0
# 19    18  04/21/2012      İzmir  Big Cities  0.200000  0.533333  3.0  1.0
# 44    43  09/24/2009     Ankara  Big Cities  0.250000  0.666667  4.0  1.0
# 122  121  11/13/2004      İzmir  Big Cities  0.250000  0.533333  4.0  2.0
# 54    53  03/29/2013     Samsun       Other  0.250000  0.533333  3.0  1.0
# 83    82  02/23/2010    Karabük       Other  0.500000  0.533333  3.0  2.0
# 59    58  04/11/2012   İstanbul  Big Cities  0.250000  0.533333  5.0  2.0
# 91    90  08/08/2013   İstanbul  Big Cities  0.133333  0.800000  6.0  2.0
# 36    35  05/08/1996      Adana       Other  0.200000  0.533333  3.0  1.0
# ...

# %%
y_test
# Out:
# 35     0.250000
# 33     0.333333
# 77     0.500000
# 5      0.333333
# 19     0.250000
# 44     0.500000
# 122    0.500000
# 54     0.333333
# 83     0.500000
# 59     0.333333
# 91     0.083333
# 36     0.250000
# 90     1.000000
# 134    0.250000
# Name: P-1, dtype: float64

# %% [markdown]
# ## 7. Calculate the R2_Score

# %%
y_pred = lr.predict(x_test)
y_pred

# %%
lr.score(x_test, y_test)

# %%
from sklearn.metrics import r2_score
r2_score(lr.predict(x_test),y_test)

# %%
r2_score(lr.predict(x_train),y_train)
